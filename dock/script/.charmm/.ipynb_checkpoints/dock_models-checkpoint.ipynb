# %%
#Use FFTDock and refinment to dock ligands into AlphaFold models with FAD cofactor
#Inputs:
    #cofactor/pdb_with_fad/tropb.pdb
    #dock/ligands/2.pdb
    #dock/ligands/2.str #CGenFF stream file
    #toppar
    #dock/inp
#Outputs:
    #dock/grid/tropb_fftdock_3.bin
    #dock/poses/tropb_2_fftdock_3
    #dock/poses/tropb_2_prot_0.75
    #dock/scores/
    
import os 
import re
import pandas as pd
import numpy as np
os.chdir('/home/azamh/demo/seq_struct_func/dock')

# %%
#Define protein and ligand to dock
charmm_exec = '/home/wyujin/CHARMM7/stable-release/install/test/bin/charmm'
protein = 'tropb'
ligand = '2'
liganddir = './ligands'
faddir = '../cofactor/pdb_with_fad'
fftdock_dockdir = os.path.join('poses', f'{protein}_{ligand}_fftdock_3')
fftdock_eps = 3
griddir = './grid'
scriptdir = './inp'
fftdock_poses = 500
fftdock_scorefile = f'scores/{protein}_{ligand}_fftdock_3.dat'

# %%
#Create directory for fftdock poses
os.makedirs(fftdock_dockdir, exist_ok = True)

# %%
#Run FFTDock
#Generate FFTDOCK conformers
def fftdock(protein: str,
            ligand: str,
            dockdir: str,
            scorefile: str,
            epsilon: int,
            griddir:str,
            scriptdir:str,
            faddir:str,
            liganddir:str,
            num_poses:int):
    
    #generate fftdock grid with fftdock.inp
    gridfile = f'{griddir}/{protein}_fftdock_{epsilon}.bin'
    if not os.path.isfile(gridfile):
        grid_gen_out = os.popen(f'{charmm_exec} -i {scriptdir}/fftdock.inp makegrid=1 protein={protein} epsilon={epsilon} scriptdir={scriptdir} faddir={faddir} gridfile={gridfile}').read()
        print(grid_gen_out)
        
        if not os.path.isfile(gridfile):
            raise ValueError('Grid Generation Failed! See CHARMM Out')
    
    #generate fftdock conformations
    fftdock_out = os.popen(f'{charmm_exec} -i {scriptdir}/fftdock.inp griddock=1 protein={protein} faddir={faddir} liganddir={liganddir} ' + 
                           f'ligand={ligand} poses={num_poses}  dockdir={dockdir} scorefile={scorefile} epsilon={epsilon} gridfile={gridfile} scriptdir={scriptdir}').read()
    print(fftdock_out)
    
    return
# Out:
# [gollum154][[12321,1],0][../../../../../openmpi-3.1.2/opal/mca/btl/openib/btl_openib_component.c:1671:init_one_device] error obtaining device attributes for mlx5_0 errno says Protocol not supported
# --------------------------------------------------------------------------
# WARNING: There was an error initializing an OpenFabrics device.
#
#   Local host:   gollum154
#   Local device: mlx5_0
# --------------------------------------------------------------------------
#  Parameter: GRIDDOCK <- "1"
#  Parameter: PROTEIN <- "TROPB"
#  Parameter: FADDIR <- "../COFACTOR/PDB_WITH_FAD"
#  Parameter: LIGANDDIR <- "./LIGANDS"
#  Parameter: LIGAND <- "2"
#  Parameter: POSES <- "500"
#  Parameter: DOCKDIR <- "POSES/TROPB_2_FFTDOCK_3"
#  Parameter: SCOREFILE <- "SCORES/TROPB_2_FFTDOCK_3.DAT"
#  Parameter: EPSILON <- "3"
#  Parameter: GRIDFILE <- "./GRID/TROPB_FFTDOCK_3.BIN"
#  Parameter: SCRIPTDIR <- "./INP"
# 1
#                  Chemistry at HARvard Macromolecular Mechanics
#            (CHARMM) - Developmental Version 47b1     August 15, 2022
#                              Git commit ID 83ff627
#        Copyright(c) 1984-2022  President and Fellows of Harvard College
#                               All Rights Reserved
#   Current operating system: Linux-3.10.0-1127.el7.x86_64(x86_64)@gollum154.ls
#                  Created on 12/7/22 at 12:22:00 by user: azamh
#
#             Maximum number of ATOMS:    360720, and RESidues:      120240
#  RDTITL> *THIS SCRIPT USES FFTDOCK TO POSITION SPECIFIED LIGAND INTO STRUCTURE
#  RDTITL> *
#
#  CHARMM>
#
#  CHARMM>    !specify protein, ligand, and whether to generate grid or dock with ligand
#  CHARMM>
#
#  CHARMM>    !stream docking params
#  CHARMM>    stream @scriptdir/docking_params.str
#  Parameter: SCRIPTDIR -> "./INP"
#  VOPEN> Attempting to open::./inp/docking_params.str::
#  OPNLGU> Unit 99 opened for READONLY access to ./inp/docking_params.str
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> *STREAM FILE FOR DOCKING
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    !toppar
#  CHARMM>    set toppardir = /home/azamh/anc_model/lig_toppar/toppar
#  Parameter: TOPPARDIR <- "/HOME/AZAMH/ANC_MODEL/LIG_TOPPAR/TOPPAR"
#
#  CHARMM>    set strdir = /home/azamh/anc_model/lig_toppar/str_ligands
#  Parameter: STRDIR <- "/HOME/AZAMH/ANC_MODEL/LIG_TOPPAR/STR_LIGANDS"
#
#  CHARMM>
#
#  CHARMM>    !Grid center from tropb + 3mo
#  CHARMM>    set xceng = 57.135381
#  Parameter: XCENG <- "57.135381"
#
#  CHARMM>    set yceng = 45.1752381
#  Parameter: YCENG <- "45.1752381"
#
#  CHARMM>    set zceng = 46.0617619
#  Parameter: ZCENG <- "46.0617619"
#
#  CHARMM>
#
#  CHARMM>    !Fftdock params
#  CHARMM>    set xmax = 12
#  Parameter: XMAX <- "12"
#
#  CHARMM>
#
#  CHARMM>    !Protein params
#  CHARMM>    set pseg = PROA
#  Parameter: PSEG <- "PROA"
#
#  CHARMM>
#
#  CHARMM>    !Lig params
#  CHARMM>    set lseg = LIGA
#  Parameter: LSEG <- "LIGA"
#
#  CHARMM>    set ligdir = /home/azamh/anc_model/lig_toppar/pdb_ligands
#  Parameter: LIGDIR <- "/HOME/AZAMH/ANC_MODEL/LIG_TOPPAR/PDB_LIGANDS"
#
#  CHARMM>
#
#  CHARMM>    RETURN
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM     5
#
#  CHARMM>
#
#  CHARMM>    if @?makegrid eq 1 goto makegrid
#  Comparing "0" and "1".
#  IF test evaluated as false.  Skipping command
#
#  CHARMM>    if @?griddock eq 1 goto griddock
#  Comparing "1" and "1".
#  IF test evaluated as true.  Performing command
#
#  CHARMM>
#
#  CHARMM>    !read rtf
#  CHARMM>    read rtf card name @toppardir/top_all36_prot.rtf
#  Parameter: TOPPARDIR -> "/HOME/AZAMH/ANC_MODEL/LIG_TOPPAR/TOPPAR"
#  VOPEN> Attempting to open::/home/azamh/anc_model/lig_toppar/toppar/top_all36_prot.rtf::
#  MAINIO> Residue topology file being read from unit  90.
#  TITLE> *>>>>>>>>CHARMM36 ALL-HYDROGEN TOPOLOGY FILE FOR PROTEINS <<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> MAY 2011 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  VCLOSE: Closing unit   90 with status "KEEP"
#
#  CHARMM>    read param card name @toppardir/par_all36m_prot.prm flex
#  Parameter: TOPPARDIR -> "/HOME/AZAMH/ANC_MODEL/LIG_TOPPAR/TOPPAR"
#  VOPEN> Attempting to open::/home/azamh/anc_model/lig_toppar/toppar/par_all36m_prot.prm::
#
#           PARAMETER FILE BEING READ FROM UNIT 90
#  TITLE> *>>>> CHARMM36 ALL-HYDROGEN PARAMETER FILE FOR PROTEINS <<<<<<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> JAN. 2016 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   90 with status "KEEP"
#
#  CHARMM>    read rtf card name @toppardir/top_all36_cgenff.rtf append
#  Parameter: TOPPARDIR -> "/HOME/AZAMH/ANC_MODEL/LIG_TOPPAR/TOPPAR"
#  VOPEN> Attempting to open::/home/azamh/anc_model/lig_toppar/toppar/top_all36_cgenff.rtf::
#  MAINIO> Residue topology file being read from unit  90.
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *          CGENFF: TOPOLOGY FOR THE CHARMM GENERAL FORCE FIELD V. 4.6          *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *
#
#  DRUDES PARTICLES WILL BE GENERATED AUTOMATICALLY FOR ALL ATOMS WITH NON-ZERO ALPHA
#  Thole-type dipole screening, Slater-Delta shape {S(u) = 1 - (1+u/2)*exp(-u)}, default radius =  1.300000
#  VCLOSE: Closing unit   90 with status "KEEP"
#
#  CHARMM>
#
#  CHARMM>    bomlev -2
#
#  CHARMM>    read param card name @toppardir/par_all36_cgenff.prm flex append
#  Parameter: TOPPARDIR -> "/HOME/AZAMH/ANC_MODEL/LIG_TOPPAR/TOPPAR"
#  VOPEN> Attempting to open::/home/azamh/anc_model/lig_toppar/toppar/par_all36_cgenff.prm::
#
#           PARAMETER FILE BEING READ FROM UNIT 90
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *         CGENFF: PARAMETERS FOR THE CHARMM GENERAL FORCE FIELD V. 4.6         *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *  2017/8: IF PROTEIN, NUCLEIC ACID AND CARBOHYDRATE TOPOLOGY AND PARAMETER FILES
#  TITLE> *  ARE NOT READ PRIOR TO THE CGENFF FILES "WARNING: ATOMS IN NBFIX ' errors will
#  TITLE> *  BE ENCOUNTERED.  THESE CAN BE PASSED BY SETTING BOMLEV ( -2) PRIOR TO READING
#  TITLE> *  THIS FILE. IN ADDITION, WHEN GENERATING AROMATIC HALOGENS (CL, BR, I) WITH
#  TITLE> *  PRE C41B/C42A VERSIONS OF CHARMM "MISSING PARAMETER" ERRORS WILL BE
#  TITLE> *  ENCOUNTERED THAT ALSO REQUIRE SETTING BOMLEV ( -2).
#  TITLE> *
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL  CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L CLGR   -3.60000   3.18000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL  CLGR   -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL  BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L BRGR   -3.65000   3.33000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL  BRGR   -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1  CLGR   -0.40000   3.88000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2  CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3  CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4  CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1  CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1  BRGR   -0.30000   4.05000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2  BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3  BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4  BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1  BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C BRGR   -0.27000   3.52000 DONT EXIST
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   90 with status "KEEP"
#
#  CHARMM>    stream @toppardir/st2_fadh.str
#  Parameter: TOPPARDIR -> "/HOME/AZAMH/ANC_MODEL/LIG_TOPPAR/TOPPAR"
#  VOPEN> Attempting to open::/home/azamh/anc_model/lig_toppar/toppar/st2_fadh.str::
#  OPNLGU> Unit 99 opened for READONLY access to /home/azamh/anc_model/lig_toppar/toppar/st2_fadh.str
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> * TOPPAR STREAM FILE GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 1.0.0
#  RDTITL> * FOR USE WITH CGENFF VERSION 3.0.1
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    read rtf card append
#  MAINIO> Residue topology file being read from unit  99.
#  RDTITL> * TOPOLOGIES GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 1.0.0
#  RDTITL> *
# *** WARNING **** residue FAD  already exists (old one deleted)
#
#       ***** LEVEL  1 WARNING FROM <RTFRDR> *****
#       ***** Residue already exists.
#       ******************************************
#       BOMLEV ( -2) IS NOT REACHED. WRNLEV IS  5
#
#           RESI FAD           -2.000
#  There were   1 warning(s) from RTFRDR.
#
#  CHARMM>
#
#  CHARMM>    read param card flex append
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * PARAMETERS GENERATED BY ANALOGY BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 1.0.0
#  RDTITL> *
#  PARRDR> Error: Repeated BOND parameter (   319): CG2O  NG2D is replaced
#  PARRDR> Error: Repeated BOND parameter (   466): CG2R  NG2D is replaced
#  PARRDR> Error: Repeated BOND parameter (   575): CG32  NG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (   814): NG2D  CG2O  NG2S is replaced
#  PARRDR> Error: Repeated ANGLE parameter (   815): NG2D  CG2O  OG2D is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1012): CG2O  CG2R  CG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1014): CG2O  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1171): CG2R  CG2R  NG2D is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1175): CG2R  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1199): NG2D  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1663): CG31  CG32  NG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  1759): NG2R  CG32  HGA2 is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  2238): CG2O  NG2D  CG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  2373): CG2R  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  2374): CG2R  NG2R  CG32 is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  2394): CG2R  NG2R  CG32 is replaced
#  PARRDR> Error: Repeated ANGLE parameter (  2448): CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  1857): NG2S  CG2O  CG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  1859): NG2S  CG2O  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  1862): OG2D  CG2O  CG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  1864): OG2D  CG2O  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2181): CG2R  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2182): CG2R  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2181): CG2R  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2182): CG2R  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2264): OG2D  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2643): NG2S  CG2O  NG2D  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2644): OG2D  CG2O  NG2D  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2661): NG2D  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2662): NG2D  CG2O  NG2S  HGP1 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  2687): OG2D  CG2O  NG2S  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3724): NG2R  CG2R  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3794): CG2O  CG2R  CG2R  NG2D is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3795): CG2O  CG2R  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3804): NG2R  CG2R  CG2R  NG2D is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3805): NG2R  CG2R  CG2R  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  3989): CG2O  CG2R  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4007): CG2R  CG2R  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4008): CG2R  CG2R  NG2R  CG32 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4435): CG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4441): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4442): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4443): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4441): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4442): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4443): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4441): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4442): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4443): NG2R  CG2R  NG2D  CG2O is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4484): CG2R  CG2R  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4485): CG2R  CG2R  NG2R  CG32 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4493): NG2D  CG2R  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  4496): NG2D  CG2R  NG2R  CG32 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5014): CG32  CG31  CG31  OG31 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5032): OG31  CG31  CG31  OG31 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5103): CG31  CG31  CG32  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5105): CG31  CG31  CG32  OG30 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5193): OG31  CG31  CG32  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5222): HGA1  CG31  CG32  NG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  6107): CG31  CG32  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  6108): CG31  CG32  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  6112): HGA2  CG32  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated DIHE parameter (  6114): HGA2  CG32  NG2R  CG2R is replaced
#  PARRDR> Error: Repeated IMPH parameter (   161): CG2O  NG2D  NG2S  OG2D is replaced
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>    RETURN
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM     5
#
#  CHARMM>    stream @liganddir/@ligand.str
#  Parameter: LIGANDDIR -> "./LIGANDS"
#  Parameter: LIGAND -> "2"
#  VOPEN> Attempting to open::./ligands/2.str::
#  OPNLGU> Unit 99 opened for READONLY access to ./ligands/2.str
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> * TOPPAR STREAM FILE GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.3.0
#  RDTITL> * FOR USE WITH CGENFF VERSION 4.3
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    read rtf card append
#  MAINIO> Residue topology file being read from unit  99.
#  RDTITL> * TOPOLOGIES GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.3.0
#  RDTITL> *
#
#  CHARMM>
#
#  CHARMM>    read param card flex append
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * PARAMETERS GENERATED BY ANALOGY BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.3.0
#  RDTITL> *
#  PARRDR> Error: Repeated DIHE parameter (  5715): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5716): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5717): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5718): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5719): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5715): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5716): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5717): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5718): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5719): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5715): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5716): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5717): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5718): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5719): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5715): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5716): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5717): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5718): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5719): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5715): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5716): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5717): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5718): CG2O  CG32  CG32  CG33 is replaced
#  PARRDR> Error: Repeated DIHE parameter (  5719): CG2O  CG32  CG32  CG33 is replaced
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>    RETURN
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM     5
#
#  CHARMM>    bomlev 0
#
#  CHARMM>
#
#  CHARMM>    !read in ligand
#  CHARMM>    read sequ pdb name @liganddir/@ligand.pdb
#  Parameter: LIGANDDIR -> "./LIGANDS"
#  Parameter: LIGAND -> "2"
#  VOPEN> Attempting to open::./ligands/2.pdb::
#  MAINIO> Sequence information being read from unit  90.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --     1 RESIDUES
#           LIG
#  VCLOSE: Closing unit   90 with status "KEEP"
#
#  CHARMM>    generate @lseg setup
#  Parameter: LSEG -> "LIGA"
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  GENPSF> Segment   1 has been generated. Its identifier is LIGA.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        1   Number of residues   =        1
#          Number of atoms         =       32   Number of groups     =        1
#          Number of bonds         =       32   Number of angles     =       55
#          Number of dihedrals     =       72   Number of impropers  =        2
#          Number of cross-terms   =        0
#          Number of HB acceptors  =        0   Number of HB donors  =        0
#          Number of NB exclusions =        0   Total charge =   -1.00000
#  QXFORM> Expanded format used.
#          More than 4 character atom type used.
#
#  CHARMM>    auto angle dihe
#  AUTOGEN: All angles are removed and regenerated.
#  AUTOGEN: All dihedrals are removed and regenerated.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        1   Number of residues   =        1
#          Number of atoms         =       32   Number of groups     =        1
#          Number of bonds         =       32   Number of angles     =       55
#          Number of dihedrals     =       72   Number of impropers  =        2
#          Number of cross-terms   =        0
#          Number of HB acceptors  =        0   Number of HB donors  =        0
#          Number of NB exclusions =        0   Total charge =   -1.00000
#
#  CHARMM>    read coor pdb name @liganddir/@ligand.pdb resid
#  Parameter: LIGANDDIR -> "./LIGANDS"
#  Parameter: LIGAND -> "2"
#  VOPEN> Attempting to open::./ligands/2.pdb::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 90
#  TITLE>  *
#  VCLOSE: Closing unit   90 with status "KEEP"
#
#  CHARMM>
#
#  CHARMM>    !! Check if it has lone pair
#  CHARMM>    !! If it has lone pair -- redistribute this charge
#  CHARMM>    define lp select type lp* .and. segid @lseg end
#  Parameter: LSEG -> "LIGA"
#  SELRPN>      0 atoms have been selected out of     32
#
#  CHARMM>    if ?nsel .gt. 0 then
#  RDCMND substituted energy or value "?NSEL" to "0"
#  Comparing "0" and "0".
#  IF test evaluated as false.  Skip to ELSE or ENDIF
#
#  CHARMM>
#
#  CHARMM>    ! copy the original coordinates to comparison coordinates
#  CHARMM>    print coor selec segid @lseg end
#  Parameter: LSEG -> "LIGA"
#  SELRPN>     32 atoms have been selected out of     32
#
#           COORDINATE FILE MODULE
#  TITLE>  *THIS SCRIPT USES FFTDOCK TO POSITION SPECIFIED LIGAND INTO STRUCTURE
#  TITLE>  *
#         32  EXT
#          1         1  LIG       O1              0.9840000000        0.4590000000       -0.2050000000  LIGA      1               0.0000000000
#          2         1  LIG       C1              2.1110000000        0.0370000000        0.0650000000  LIGA      1               0.0000000000
#          3         1  LIG       C2              2.6910000000        0.1720000000        1.4680000000  LIGA      1               0.0000000000
#          4         1  LIG       C3              1.6210000000        0.0900000000        2.5500000000  LIGA      1               0.0000000000
#          5         1  LIG       C4              2.2250000000        0.2750000000        3.9340000000  LIGA      1               0.0000000000
#          6         1  LIG       C5              2.9460000000       -0.6420000000       -1.0080000000  LIGA      1               0.0000000000
#          7         1  LIG       C6              4.4310000000       -0.4060000000       -0.9000000000  LIGA      1               0.0000000000
#          8         1  LIG       C7              5.0370000000        0.8530000000       -0.9630000000  LIGA      1               0.0000000000
#          9         1  LIG       C8              4.2370000000        2.0500000000       -1.3110000000  LIGA      1               0.0000000000
#         10         1  LIG       O2              4.6260000000        3.1840000000       -1.0420000000  LIGA      1               0.0000000000
#         11         1  LIG       C9              6.4090000000        0.9870000000       -0.7040000000  LIGA      1               0.0000000000
#         12         1  LIG       O3              7.0120000000        2.2250000000       -0.6850000000  LIGA      1               0.0000000000
#         13         1  LIG       C10             7.2080000000       -0.1470000000       -0.4520000000  LIGA      1               0.0000000000
#         14         1  LIG       C11             8.6930000000        0.0120000000       -0.2040000000  LIGA      1               0.0000000000
#         15         1  LIG       C12             6.6450000000       -1.4560000000       -0.4440000000  LIGA      1               0.0000000000
#         16         1  LIG       O4              7.3140000000       -2.5250000000       -0.2430000000  LIGA      1               0.0000000000
#         17         1  LIG       C13             5.2550000000       -1.5220000000       -0.6640000000  LIGA      1               0.0000000000
#         18         1  LIG       H1              3.2110000000        1.1360000000        1.5190000000  LIGA      1               0.0000000000
#         19         1  LIG       H2              3.4220000000       -0.6250000000        1.6350000000  LIGA      1               0.0000000000
#         20         1  LIG       H3              1.1190000000       -0.8830000000        2.4980000000  LIGA      1               0.0000000000
#         21         1  LIG       H4              0.8500000000        0.8530000000        2.3900000000  LIGA      1               0.0000000000
#         22         1  LIG       H5              3.0090000000       -0.4650000000        4.1230000000  LIGA      1               0.0000000000
#         23         1  LIG       H6              1.4560000000        0.1600000000        4.7040000000  LIGA      1               0.0000000000
#         24         1  LIG       H7              2.6640000000        1.2730000000        4.0370000000  LIGA      1               0.0000000000
#         25         1  LIG       H8              2.6010000000       -0.3080000000       -1.9930000000  LIGA      1               0.0000000000
#         26         1  LIG       H9              2.7150000000       -1.7120000000       -0.9450000000  LIGA      1               0.0000000000
#         27         1  LIG       H10             3.2780000000        1.8910000000       -1.8270000000  LIGA      1               0.0000000000
#         28         1  LIG       H11             6.3040000000        2.9030000000       -0.7150000000  LIGA      1               0.0000000000
#         29         1  LIG       H12             9.0030000000        1.0590000000       -0.1410000000  LIGA      1               0.0000000000
#         30         1  LIG       H13             9.2620000000       -0.4480000000       -1.0190000000  LIGA      1               0.0000000000
#         31         1  LIG       H14             8.9740000000       -0.4550000000        0.7470000000  LIGA      1               0.0000000000
#         32         1  LIG       H15             4.8070000000       -2.5190000000       -0.6340000000  LIGA      1               0.0000000000
#
#  CHARMM>    coor copy comp
#  SELECTED COORDINATES COPIED TO THE COMPARISON SET.
#
#
#  CHARMM>
#
#  CHARMM>    !read in grid
#  CHARMM>    open unit 1 read unform name @gridfile
#  Parameter: GRIDFILE -> "./GRID/TROPB_FFTDOCK_3.BIN"
#  VOPEN> Attempting to open::./grid/tropb_fftdock_3.bin::
#  OPNLGU> Unit  1 opened for READONLY access to ./grid/tropb_fftdock_3.bin
#
#  CHARMM>    fftg read unit 1
#  Grid potentials read from binary file on unit   1
# *THIS SCRIPT USES FFTDOCK TO POSITION SPECIFIED LIGAND INTO STRUCTURE
# *  DATE:    12/ 7/22     12:22: 0      CREATED BY USER: azamh
# *
#  GridSetUp: Grid potentials will be set-up for  26 atom types plus electrostatics
#  GridSetUp: and read from unit   1
#  GridSetUp: Grid centered at  57.13538  45.17524  46.06176
#  GridSetUp: Hydrogen bond grids   0.00000   0.00000   0.00000
#  GridSetUp: Grid runs from (X)  51.13538 -  63.13538
#  GridSetUp: Grid runs from (Y)  39.17524 -  51.17524
#  GridSetUp: Grid runs from (Z)  40.06176 -  52.06176
#
#  GridSetUp: With a grid spacing of   0.50000
#  GridSetUp: Force constant at grid edge set to    300.000 kcal/mol/A^2
#
#  CHARMM>    close unit 1
#  VCLOSE: Closing unit    1 with status "KEEP"
#
#  CHARMM>
#
#  CHARMM>    !get initial energies
#  CHARMM>    coor tranlate xdir 400 ydir 400 zdir 400 select segid @lseg end
#  Parameter: LSEG -> "LIGA"
#  SELRPN>     32 atoms have been selected out of     32
#  TRANSLATION VECTOR   400.000000  400.000000  400.000000
#  SELECTED COORDINATES TRANSLATED IN THE MAIN SET.
#
#
#  CHARMM>    energy
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSHIft   VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 14.000 CTEXNB =999.000 CTONNB = 10.000 CTOFNB = 12.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are        0 atom  pairs and        0 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  <MAKINB> with mode   5 found     87 exclusions and     69 interactions(1-4)
#  <MAKGRP> found      0 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR      481 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#       409 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# ENER ENR:  Eval#     ENERgy      Delta-E         GRMS
# ENER INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# ENER EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
#  ----------       ---------    ---------    ---------    ---------    ---------
# ENER>        0    -11.80985      0.00000     10.52596
# ENER INTERN>        4.66959      4.67354      0.53870      6.98584      0.00167
# ENER EXTERN>       14.43074    -43.10994      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  CHARMM>    calc sepener = ?ener
#  RDCMND substituted energy or value "?ENER" to "-11.8098452"
# Evaluating: -11.8098452
#  Parameter: SEPENER <- "-11.8098452"
#
#  CHARMM>    calc sepvdw = ?vdw
#  RDCMND substituted energy or value "?VDW" to "14.4307422"
# Evaluating: 14.4307422
#  Parameter: SEPVDW <- "14.4307422"
#
#  CHARMM>    calc sepelec = ?elec
#  RDCMND substituted energy or value "?ELEC" to "-43.1099352"
# Evaluating: -43.1099352
#  Parameter: SEPELEC <- "-43.1099352"
#
#  CHARMM>    calc sepegrid = ?grvd + ?grel
#  RDCMND substituted energy or value "?GRVD" to "0"
#  RDCMND substituted energy or value "?GREL" to "0"
# Evaluating: 0+0
#  Parameter: SEPEGRID <- "0"
#
#  CHARMM>    calc sepgrvd = ?grvd
#  RDCMND substituted energy or value "?GRVD" to "0"
# Evaluating: 0
#  Parameter: SEPGRVD <- "0"
#
#  CHARMM>    calc sepgrel = ?grel
#  RDCMND substituted energy or value "?GREL" to "0"
# Evaluating: 0
#  Parameter: SEPGREL <- "0"
#
#  CHARMM>
#
#  CHARMM>
#
#  CHARMM>    !dock with fftg
#  CHARMM>    set nsave = 36000
#  Parameter: NSAVE <- "36000"
#
#  CHARMM>    open unit 2 read form name @toppardir/fftdock_rotation_3.qua
#  Parameter: TOPPARDIR -> "/HOME/AZAMH/ANC_MODEL/LIG_TOPPAR/TOPPAR"
#  VOPEN> Attempting to open::/home/azamh/anc_model/lig_toppar/toppar/fftdock_rotation_3.qua::
#  OPNLGU> Unit  2 opened for READONLY access to /home/azamh/anc_model/lig_toppar/toppar/fftdock_rotation_3.qua
#
#  CHARMM>    fftg lcon ncon 1 icon 1  nrok @nsave quau 2 sizb 100 select segid @lseg end
#  Parameter: NSAVE -> "36000"
#  Parameter: LSEG -> "LIGA"
# Num of GPU Devices: 4
# The device 0 is used.
#   GPU Devices Name: NVIDIA GeForce RTX 2080 Ti
#   total global devices memory: 11019 MB
# FFTDOCK - num of orientations: 36864
# FFTDOCK - batch_size:   100
# FFTDOCK - num_batch:   369
#  SELRPN>     32 atoms have been selected out of     32
# <FFTDock> Initializing ligand grid
# Total number of grids =    27
# Types of VDW grid used  =     9
# BatchId / Total =     1 /   369
# BatchId / Total =     2 /   369
# BatchId / Total =     3 /   369
# BatchId / Total =     4 /   369
# BatchId / Total =     5 /   369
# BatchId / Total =     6 /   369
# BatchId / Total =     7 /   369
# BatchId / Total =     8 /   369
# BatchId / Total =     9 /   369
# BatchId / Total =    10 /   369
# BatchId / Total =    11 /   369
# BatchId / Total =    12 /   369
# BatchId / Total =    13 /   369
# BatchId / Total =    14 /   369
# BatchId / Total =    15 /   369
# BatchId / Total =    16 /   369
# BatchId / Total =    17 /   369
# BatchId / Total =    18 /   369
# BatchId / Total =    19 /   369
# BatchId / Total =    20 /   369
# BatchId / Total =    21 /   369
# BatchId / Total =    22 /   369
# BatchId / Total =    23 /   369
# BatchId / Total =    24 /   369
# BatchId / Total =    25 /   369
# BatchId / Total =    26 /   369
# BatchId / Total =    27 /   369
# BatchId / Total =    28 /   369
# BatchId / Total =    29 /   369
# BatchId / Total =    30 /   369
# BatchId / Total =    31 /   369
# BatchId / Total =    32 /   369
# BatchId / Total =    33 /   369
# BatchId / Total =    34 /   369
# BatchId / Total =    35 /   369
# BatchId / Total =    36 /   369
# BatchId / Total =    37 /   369
# BatchId / Total =    38 /   369
# BatchId / Total =    39 /   369
# BatchId / Total =    40 /   369
# BatchId / Total =    41 /   369
# BatchId / Total =    42 /   369
# BatchId / Total =    43 /   369
# BatchId / Total =    44 /   369
# BatchId / Total =    45 /   369
# BatchId / Total =    46 /   369
# BatchId / Total =    47 /   369
# BatchId / Total =    48 /   369
# BatchId / Total =    49 /   369
# BatchId / Total =    50 /   369
# BatchId / Total =    51 /   369
# BatchId / Total =    52 /   369
# BatchId / Total =    53 /   369
# BatchId / Total =    54 /   369
# BatchId / Total =    55 /   369
# BatchId / Total =    56 /   369
# BatchId / Total =    57 /   369
# BatchId / Total =    58 /   369
# BatchId / Total =    59 /   369
# BatchId / Total =    60 /   369
# BatchId / Total =    61 /   369
# BatchId / Total =    62 /   369
# BatchId / Total =    63 /   369
# BatchId / Total =    64 /   369
# BatchId / Total =    65 /   369
# BatchId / Total =    66 /   369
# BatchId / Total =    67 /   369
# BatchId / Total =    68 /   369
# BatchId / Total =    69 /   369
# BatchId / Total =    70 /   369
# BatchId / Total =    71 /   369
# BatchId / Total =    72 /   369
# BatchId / Total =    73 /   369
# BatchId / Total =    74 /   369
# BatchId / Total =    75 /   369
# BatchId / Total =    76 /   369
# BatchId / Total =    77 /   369
# BatchId / Total =    78 /   369
# BatchId / Total =    79 /   369
# BatchId / Total =    80 /   369
# BatchId / Total =    81 /   369
# BatchId / Total =    82 /   369
# BatchId / Total =    83 /   369
# BatchId / Total =    84 /   369
# BatchId / Total =    85 /   369
# BatchId / Total =    86 /   369
# BatchId / Total =    87 /   369
# BatchId / Total =    88 /   369
# BatchId / Total =    89 /   369
# BatchId / Total =    90 /   369
# BatchId / Total =    91 /   369
# BatchId / Total =    92 /   369
# BatchId / Total =    93 /   369
# BatchId / Total =    94 /   369
# BatchId / Total =    95 /   369
# BatchId / Total =    96 /   369
# BatchId / Total =    97 /   369
# BatchId / Total =    98 /   369
# BatchId / Total =    99 /   369
# BatchId / Total =   100 /   369
# BatchId / Total =   101 /   369
# BatchId / Total =   102 /   369
# BatchId / Total =   103 /   369
# BatchId / Total =   104 /   369
# BatchId / Total =   105 /   369
# BatchId / Total =   106 /   369
# BatchId / Total =   107 /   369
# BatchId / Total =   108 /   369
# BatchId / Total =   109 /   369
# BatchId / Total =   110 /   369
# BatchId / Total =   111 /   369
# BatchId / Total =   112 /   369
# BatchId / Total =   113 /   369
# BatchId / Total =   114 /   369
# BatchId / Total =   115 /   369
# BatchId / Total =   116 /   369
# BatchId / Total =   117 /   369
# BatchId / Total =   118 /   369
# BatchId / Total =   119 /   369
# BatchId / Total =   120 /   369
# BatchId / Total =   121 /   369
# BatchId / Total =   122 /   369
# BatchId / Total =   123 /   369
# BatchId / Total =   124 /   369
# BatchId / Total =   125 /   369
# BatchId / Total =   126 /   369
# BatchId / Total =   127 /   369
# BatchId / Total =   128 /   369
# BatchId / Total =   129 /   369
# BatchId / Total =   130 /   369
# BatchId / Total =   131 /   369
# BatchId / Total =   132 /   369
# BatchId / Total =   133 /   369
# BatchId / Total =   134 /   369
# BatchId / Total =   135 /   369
# BatchId / Total =   136 /   369
# BatchId / Total =   137 /   369
# BatchId / Total =   138 /   369
# BatchId / Total =   139 /   369
# BatchId / Total =   140 /   369
# BatchId / Total =   141 /   369
# BatchId / Total =   142 /   369
# BatchId / Total =   143 /   369
# BatchId / Total =   144 /   369
# BatchId / Total =   145 /   369
# BatchId / Total =   146 /   369
# BatchId / Total =   147 /   369
# BatchId / Total =   148 /   369
# BatchId / Total =   149 /   369
# BatchId / Total =   150 /   369
# BatchId / Total =   151 /   369
# BatchId / Total =   152 /   369
# BatchId / Total =   153 /   369
# BatchId / Total =   154 /   369
# BatchId / Total =   155 /   369
# BatchId / Total =   156 /   369
# BatchId / Total =   157 /   369
# BatchId / Total =   158 /   369
# BatchId / Total =   159 /   369
# BatchId / Total =   160 /   369
# BatchId / Total =   161 /   369
# BatchId / Total =   162 /   369
# BatchId / Total =   163 /   369
# BatchId / Total =   164 /   369
# BatchId / Total =   165 /   369
# BatchId / Total =   166 /   369
# BatchId / Total =   167 /   369
# BatchId / Total =   168 /   369
# BatchId / Total =   169 /   369
# BatchId / Total =   170 /   369
# BatchId / Total =   171 /   369
# BatchId / Total =   172 /   369
# BatchId / Total =   173 /   369
# BatchId / Total =   174 /   369
# BatchId / Total =   175 /   369
# BatchId / Total =   176 /   369
# BatchId / Total =   177 /   369
# BatchId / Total =   178 /   369
# BatchId / Total =   179 /   369
# BatchId / Total =   180 /   369
# BatchId / Total =   181 /   369
# BatchId / Total =   182 /   369
# BatchId / Total =   183 /   369
# BatchId / Total =   184 /   369
# BatchId / Total =   185 /   369
# BatchId / Total =   186 /   369
# BatchId / Total =   187 /   369
# BatchId / Total =   188 /   369
# BatchId / Total =   189 /   369
# BatchId / Total =   190 /   369
# BatchId / Total =   191 /   369
# BatchId / Total =   192 /   369
# BatchId / Total =   193 /   369
# BatchId / Total =   194 /   369
# BatchId / Total =   195 /   369
# BatchId / Total =   196 /   369
# BatchId / Total =   197 /   369
# BatchId / Total =   198 /   369
# BatchId / Total =   199 /   369
# BatchId / Total =   200 /   369
# BatchId / Total =   201 /   369
# BatchId / Total =   202 /   369
# BatchId / Total =   203 /   369
# BatchId / Total =   204 /   369
# BatchId / Total =   205 /   369
# BatchId / Total =   206 /   369
# BatchId / Total =   207 /   369
# BatchId / Total =   208 /   369
# BatchId / Total =   209 /   369
# BatchId / Total =   210 /   369
# BatchId / Total =   211 /   369
# BatchId / Total =   212 /   369
# BatchId / Total =   213 /   369
# BatchId / Total =   214 /   369
# BatchId / Total =   215 /   369
# BatchId / Total =   216 /   369
# BatchId / Total =   217 /   369
# BatchId / Total =   218 /   369
# BatchId / Total =   219 /   369
# BatchId / Total =   220 /   369
# BatchId / Total =   221 /   369
# BatchId / Total =   222 /   369
# BatchId / Total =   223 /   369
# BatchId / Total =   224 /   369
# BatchId / Total =   225 /   369
# BatchId / Total =   226 /   369
# BatchId / Total =   227 /   369
# BatchId / Total =   228 /   369
# BatchId / Total =   229 /   369
# BatchId / Total =   230 /   369
# BatchId / Total =   231 /   369
# BatchId / Total =   232 /   369
# BatchId / Total =   233 /   369
# BatchId / Total =   234 /   369
# BatchId / Total =   235 /   369
# BatchId / Total =   236 /   369
# BatchId / Total =   237 /   369
# BatchId / Total =   238 /   369
# BatchId / Total =   239 /   369
# BatchId / Total =   240 /   369
# BatchId / Total =   241 /   369
# BatchId / Total =   242 /   369
# BatchId / Total =   243 /   369
# BatchId / Total =   244 /   369
# BatchId / Total =   245 /   369
# BatchId / Total =   246 /   369
# BatchId / Total =   247 /   369
# BatchId / Total =   248 /   369
# BatchId / Total =   249 /   369
# BatchId / Total =   250 /   369
# BatchId / Total =   251 /   369
# BatchId / Total =   252 /   369
# BatchId / Total =   253 /   369
# BatchId / Total =   254 /   369
# BatchId / Total =   255 /   369
# BatchId / Total =   256 /   369
# BatchId / Total =   257 /   369
# BatchId / Total =   258 /   369
# BatchId / Total =   259 /   369
# BatchId / Total =   260 /   369
# BatchId / Total =   261 /   369
# BatchId / Total =   262 /   369
# BatchId / Total =   263 /   369
# BatchId / Total =   264 /   369
# BatchId / Total =   265 /   369
# BatchId / Total =   266 /   369
# BatchId / Total =   267 /   369
# BatchId / Total =   268 /   369
# BatchId / Total =   269 /   369
# BatchId / Total =   270 /   369
# BatchId / Total =   271 /   369
# BatchId / Total =   272 /   369
# BatchId / Total =   273 /   369
# BatchId / Total =   274 /   369
# BatchId / Total =   275 /   369
# BatchId / Total =   276 /   369
# BatchId / Total =   277 /   369
# BatchId / Total =   278 /   369
# BatchId / Total =   279 /   369
# BatchId / Total =   280 /   369
# BatchId / Total =   281 /   369
# BatchId / Total =   282 /   369
# BatchId / Total =   283 /   369
# BatchId / Total =   284 /   369
# BatchId / Total =   285 /   369
# BatchId / Total =   286 /   369
# BatchId / Total =   287 /   369
# BatchId / Total =   288 /   369
# BatchId / Total =   289 /   369
# BatchId / Total =   290 /   369
# BatchId / Total =   291 /   369
# BatchId / Total =   292 /   369
# BatchId / Total =   293 /   369
# BatchId / Total =   294 /   369
# BatchId / Total =   295 /   369
# BatchId / Total =   296 /   369
# BatchId / Total =   297 /   369
# BatchId / Total =   298 /   369
# BatchId / Total =   299 /   369
# BatchId / Total =   300 /   369
# BatchId / Total =   301 /   369
# BatchId / Total =   302 /   369
# BatchId / Total =   303 /   369
# BatchId / Total =   304 /   369
# BatchId / Total =   305 /   369
# BatchId / Total =   306 /   369
# BatchId / Total =   307 /   369
# BatchId / Total =   308 /   369
# BatchId / Total =   309 /   369
# BatchId / Total =   310 /   369
# ...
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are      409 atom  pairs and      156 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR      481 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#       409 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# ENER ENR:  Eval#     ENERgy      Delta-E         GRMS
# ENER INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# ENER EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
# ENER GRID:             GrvdW       GrElec       GrHBON
#  ----------       ---------    ---------    ---------    ---------    ---------
# ENER>        0    -44.93585     -0.02657     10.74654
# ENER INTERN>        4.66968      4.67275      0.53818      6.98621      0.00164
# ENER EXTERN>       14.43020    -43.10878      0.00000      0.00000      0.00000
# ENER GRID>          1.00631    -34.13204      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  CHARMM>        calc dockener = ?ener - @sepener
#  Parameter: SEPENER -> "-11.8098452"
#  RDCMND substituted energy or value "?ENER" to "-44.9358463"
# Evaluating: -44.9358463--11.8098452
#  Parameter: DOCKENER <- "-33.1260011"
#
#  CHARMM>        calc dockvdw = ?vdw - @sepvdw
#  Parameter: SEPVDW -> "14.4307422"
#  RDCMND substituted energy or value "?VDW" to "14.4302036"
# Evaluating: 14.4302036-14.4307422
#  Parameter: DOCKVDW <- "-5.386E-04"
#
#  CHARMM>        calc dockelec = ?elec - @sepelec
#  Parameter: SEPELEC -> "-43.1099352"
#  RDCMND substituted energy or value "?ELEC" to "-43.1087765"
# Evaluating: -43.1087765--43.1099352
#  Parameter: DOCKELEC <- "1.1587E-03"
#
#  CHARMM>        calc dockegrid = ?grvd + ?grel - @sepegrid
#  Parameter: SEPEGRID -> "0"
#  RDCMND substituted energy or value "?GRVD" to "1.0063086"
#  RDCMND substituted energy or value "?GREL" to "-34.1320415"
# Evaluating: 1.0063086+-34.1320415-0
#  Parameter: DOCKEGRID <- "-33.1257329"
#
#  CHARMM>        calc dockgrvd = ?grvd - @sepgrvd
#  Parameter: SEPGRVD -> "0"
#  RDCMND substituted energy or value "?GRVD" to "1.0063086"
# Evaluating: 1.0063086-0
#  Parameter: DOCKGRVD <- "1.0063086"
#
#  CHARMM>        calc dockgrel = ?grel - @sepgrel
#  Parameter: SEPGREL -> "0"
#  RDCMND substituted energy or value "?GREL" to "-34.1320415"
# Evaluating: -34.1320415-0
#  Parameter: DOCKGREL <- "-34.1320415"
#
#  CHARMM>
#
#  CHARMM>    	coor rms selec segid @lseg end comp
#  Parameter: LSEG -> "LIGA"
#  SELRPN>     32 atoms have been selected out of     32
#  TOTAL SQUARE DIFF IS 224227.7193  DENOMINATOR IS     32.0000
#        THUS RMS DIFF IS   83.708519
#  RMS FOUND FOR SELECTED COORDINATES WITHOUT ROTATION
#
#  CHARMM>    	echo @nr @dockener @dockvdw @dockelec @dockegrid @dockgrvd @dockgrel ?rms
#  Parameter: NR -> "498"
#  Parameter: DOCKENER -> "-33.1260011"
#  Parameter: DOCKVDW -> "-5.386E-04"
#  Parameter: DOCKELEC -> "1.1587E-03"
#  Parameter: DOCKEGRID -> "-33.1257329"
#  Parameter: DOCKGRVD -> "1.0063086"
#  Parameter: DOCKGREL -> "-34.1320415"
#  RDCMND substituted energy or value "?RMS" to "83.7085194"
#
#  CHARMM>
#
#  CHARMM>        write coor card name @dockdir/@protein_@ligand_@nr.crd sele segid @lseg end
#  Parameter: DOCKDIR -> "POSES/TROPB_2_FFTDOCK_3"
#  Parameter: PROTEIN -> "TROPB"
#  Parameter: LIGAND -> "2"
#  Parameter: NR -> "498"
#  Parameter: LSEG -> "LIGA"
#  VOPEN> Attempting to open::poses/tropb_2_fftdock_3/tropb_2_498.crd::
#  RDTITL>
#  RDTITL> No title read.
#  SELRPN>     32 atoms have been selected out of     32
#  VCLOSE: Closing unit   90 with status "KEEP"
#  VCLOSE: Closing unit   90 with status "KEEP"
#
#  CHARMM>
#
#  CHARMM>        incr nr by 1
#  Parameter: NR <- "499"
#
#  CHARMM>
#
#  CHARMM>    if @nr le @totalsave goto getnr
#  Parameter: NR -> "499"
#  Parameter: TOTALSAVE -> "500"
#  Comparing "499" and "500".
#  IF test evaluated as true.  Performing command
#
#  CHARMM>    !go through each rotation
#  CHARMM>    	fftg coor icon 1 irot @nr
#  Parameter: NR -> "499"
#  Coordinates of the     1th conforamtion and the   499th rotation from FFTDOCK are copied into the main coordinates.
#
#  CHARMM>
#
#  CHARMM>        energy
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSHIft   VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 14.000 CTEXNB =999.000 CTONNB = 10.000 CTOFNB = 12.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are      409 atom  pairs and      156 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR      481 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#       409 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# ENER ENR:  Eval#     ENERgy      Delta-E         GRMS
# ENER INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# ENER EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
# ENER GRID:             GrvdW       GrElec       GrHBON
#  ----------       ---------    ---------    ---------    ---------    ---------
# ENER>        0    -44.93155     -0.00430     11.10478
# ENER INTERN>        4.67186      4.67629      0.53873      6.98602      0.00170
# ENER EXTERN>       14.42966    -43.11089      0.00000      0.00000      0.00000
# ENER GRID>         -3.63690    -29.48801      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  CHARMM>        calc dockener = ?ener - @sepener
#  Parameter: SEPENER -> "-11.8098452"
#  RDCMND substituted energy or value "?ENER" to "-44.931548"
# Evaluating: -44.931548--11.8098452
#  Parameter: DOCKENER <- "-33.1217028"
#
#  CHARMM>        calc dockvdw = ?vdw - @sepvdw
#  Parameter: SEPVDW -> "14.4307422"
#  RDCMND substituted energy or value "?VDW" to "14.429661"
# Evaluating: 14.429661-14.4307422
#  Parameter: DOCKVDW <- "-1.0812E-03"
#
#  CHARMM>        calc dockelec = ?elec - @sepelec
#  Parameter: SEPELEC -> "-43.1099352"
#  RDCMND substituted energy or value "?ELEC" to "-43.1108932"
# Evaluating: -43.1108932--43.1099352
#  Parameter: DOCKELEC <- "-9.58E-04"
#
#  CHARMM>        calc dockegrid = ?grvd + ?grel - @sepegrid
#  Parameter: SEPEGRID -> "0"
#  RDCMND substituted energy or value "?GRVD" to "-3.63690463"
#  RDCMND substituted energy or value "?GREL" to "-29.4880059"
# Evaluating: -3.63690463+-29.4880059-0
#  Parameter: DOCKEGRID <- "-33.1249105"
#
#  CHARMM>        calc dockgrvd = ?grvd - @sepgrvd
#  Parameter: SEPGRVD -> "0"
#  RDCMND substituted energy or value "?GRVD" to "-3.63690463"
# Evaluating: -3.63690463-0
#  Parameter: DOCKGRVD <- "-3.63690463"
#
#  CHARMM>        calc dockgrel = ?grel - @sepgrel
#  Parameter: SEPGREL -> "0"
#  RDCMND substituted energy or value "?GREL" to "-29.4880059"
# Evaluating: -29.4880059-0
#  Parameter: DOCKGREL <- "-29.4880059"
#
#  CHARMM>
#
#  CHARMM>    	coor rms selec segid @lseg end comp
#  Parameter: LSEG -> "LIGA"
#  SELRPN>     32 atoms have been selected out of     32
#  TOTAL SQUARE DIFF IS 228536.6908  DENOMINATOR IS     32.0000
#        THUS RMS DIFF IS   84.509003
#  RMS FOUND FOR SELECTED COORDINATES WITHOUT ROTATION
#
#  CHARMM>    	echo @nr @dockener @dockvdw @dockelec @dockegrid @dockgrvd @dockgrel ?rms
#  Parameter: NR -> "499"
#  Parameter: DOCKENER -> "-33.1217028"
#  Parameter: DOCKVDW -> "-1.0812E-03"
#  Parameter: DOCKELEC -> "-9.58E-04"
#  Parameter: DOCKEGRID -> "-33.1249105"
#  Parameter: DOCKGRVD -> "-3.63690463"
#  Parameter: DOCKGREL -> "-29.4880059"
#  RDCMND substituted energy or value "?RMS" to "84.509003"
#
#  CHARMM>
#
#  CHARMM>        write coor card name @dockdir/@protein_@ligand_@nr.crd sele segid @lseg end
#  Parameter: DOCKDIR -> "POSES/TROPB_2_FFTDOCK_3"
#  Parameter: PROTEIN -> "TROPB"
#  Parameter: LIGAND -> "2"
#  Parameter: NR -> "499"
#  Parameter: LSEG -> "LIGA"
#  VOPEN> Attempting to open::poses/tropb_2_fftdock_3/tropb_2_499.crd::
#  RDTITL>
#  RDTITL> No title read.
#  SELRPN>     32 atoms have been selected out of     32
#  VCLOSE: Closing unit   90 with status "KEEP"
#  VCLOSE: Closing unit   90 with status "KEEP"
#
#  CHARMM>
#
#  CHARMM>        incr nr by 1
#  Parameter: NR <- "500"
#
#  CHARMM>
#
#  CHARMM>    if @nr le @totalsave goto getnr
#  Parameter: NR -> "500"
#  Parameter: TOTALSAVE -> "500"
#  Comparing "500" and "500".
#  IF test evaluated as true.  Performing command
#
#  CHARMM>    !go through each rotation
#  CHARMM>    	fftg coor icon 1 irot @nr
#  Parameter: NR -> "500"
#  Coordinates of the     1th conforamtion and the   500th rotation from FFTDOCK are copied into the main coordinates.
#
#  CHARMM>
#
#  CHARMM>        energy
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSHIft   VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 14.000 CTEXNB =999.000 CTONNB = 10.000 CTOFNB = 12.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are      409 atom  pairs and      156 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR      481 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#       409 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# ENER ENR:  Eval#     ENERgy      Delta-E         GRMS
# ENER INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# ENER EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
# ENER GRID:             GrvdW       GrElec       GrHBON
#  ----------       ---------    ---------    ---------    ---------    ---------
# ENER>        0    -44.92596     -0.00559     11.47802
# ENER INTERN>        4.67253      4.67356      0.53846      6.98585      0.00165
# ENER EXTERN>       14.43156    -43.11026      0.00000      0.00000      0.00000
# ENER GRID>        -10.66466    -22.45465      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  CHARMM>        calc dockener = ?ener - @sepener
#  Parameter: SEPENER -> "-11.8098452"
#  RDCMND substituted energy or value "?ENER" to "-44.9259614"
# Evaluating: -44.9259614--11.8098452
#  Parameter: DOCKENER <- "-33.1161162"
#
#  CHARMM>        calc dockvdw = ?vdw - @sepvdw
#  Parameter: SEPVDW -> "14.4307422"
#  RDCMND substituted energy or value "?VDW" to "14.4315615"
# Evaluating: 14.4315615-14.4307422
#  Parameter: DOCKVDW <- "8.193E-04"
#
#  CHARMM>        calc dockelec = ?elec - @sepelec
#  Parameter: SEPELEC -> "-43.1099352"
#  RDCMND substituted energy or value "?ELEC" to "-43.1102642"
# Evaluating: -43.1102642--43.1099352
#  Parameter: DOCKELEC <- "-3.29E-04"
#
#  CHARMM>        calc dockegrid = ?grvd + ?grel - @sepegrid
#  Parameter: SEPEGRID -> "0"
#  RDCMND substituted energy or value "?GRVD" to "-10.6646561"
#  RDCMND substituted energy or value "?GREL" to "-22.4546548"
# Evaluating: -10.6646561+-22.4546548-0
#  Parameter: DOCKEGRID <- "-33.1193109"
#
#  CHARMM>        calc dockgrvd = ?grvd - @sepgrvd
#  Parameter: SEPGRVD -> "0"
#  RDCMND substituted energy or value "?GRVD" to "-10.6646561"
# Evaluating: -10.6646561-0
#  Parameter: DOCKGRVD <- "-10.6646561"
#
#  CHARMM>        calc dockgrel = ?grel - @sepgrel
#  Parameter: SEPGREL -> "0"
#  RDCMND substituted energy or value "?GREL" to "-22.4546548"
# Evaluating: -22.4546548-0
#  Parameter: DOCKGREL <- "-22.4546548"
#
#  CHARMM>
#
#  CHARMM>    	coor rms selec segid @lseg end comp
#  Parameter: LSEG -> "LIGA"
#  SELRPN>     32 atoms have been selected out of     32
#  TOTAL SQUARE DIFF IS 215945.0885  DENOMINATOR IS     32.0000
#        THUS RMS DIFF IS   82.147940
#  RMS FOUND FOR SELECTED COORDINATES WITHOUT ROTATION
#
#  CHARMM>    	echo @nr @dockener @dockvdw @dockelec @dockegrid @dockgrvd @dockgrel ?rms
#  Parameter: NR -> "500"
#  Parameter: DOCKENER -> "-33.1161162"
#  Parameter: DOCKVDW -> "8.193E-04"
#  Parameter: DOCKELEC -> "-3.29E-04"
#  Parameter: DOCKEGRID -> "-33.1193109"
#  Parameter: DOCKGRVD -> "-10.6646561"
#  Parameter: DOCKGREL -> "-22.4546548"
#  RDCMND substituted energy or value "?RMS" to "82.1479398"
#
#  CHARMM>
#
#  CHARMM>        write coor card name @dockdir/@protein_@ligand_@nr.crd sele segid @lseg end
#  Parameter: DOCKDIR -> "POSES/TROPB_2_FFTDOCK_3"
#  Parameter: PROTEIN -> "TROPB"
#  Parameter: LIGAND -> "2"
#  Parameter: NR -> "500"
#  Parameter: LSEG -> "LIGA"
#  VOPEN> Attempting to open::poses/tropb_2_fftdock_3/tropb_2_500.crd::
#  RDTITL>
#  RDTITL> No title read.
#  SELRPN>     32 atoms have been selected out of     32
#  VCLOSE: Closing unit   90 with status "KEEP"
#  VCLOSE: Closing unit   90 with status "KEEP"
#
#  CHARMM>
#
#  CHARMM>        incr nr by 1
#  Parameter: NR <- "501"
#
#  CHARMM>
#
#  CHARMM>    if @nr le @totalsave goto getnr
#  Parameter: NR -> "501"
#  Parameter: TOTALSAVE -> "500"
#  Comparing "501" and "500".
#  IF test evaluated as false.  Skipping command
#
#  CHARMM>
#
#  CHARMM>    grid clear
# All space for grid potentials freed
#
#  CHARMM>    delete atom select all end
#  SELRPN>     32 atoms have been selected out of     32
#
#  Message from MAPIC: Atom numbers are changed.
#
#  Message from MAPIC:          1 residues deleted.
#
#  Message from MAPIC:          1 segments deleted.
#  DELTIC:        32 bonds deleted
#  DELTIC:        55 angles deleted
#  DELTIC:        72 dihedrals deleted
#  DELTIC:         2 improper dihedrals deleted
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        0   Number of residues   =        0
#          Number of atoms         =        0   Number of groups     =        0
#          Number of bonds         =        0   Number of angles     =        0
#          Number of dihedrals     =        0   Number of impropers  =        0
#          Number of cross-terms   =        0
#          Number of HB acceptors  =        0   Number of HB donors  =        0
#          Number of NB exclusions =        0   Total charge =    0.00000
#
#  CHARMM>    stop
#  VCLOSE: Closing unit    2 with status "KEEP"
#       $$$$$$  New timer profile Local node$$$$$
#    List time                       0.06 Other:            0.00
#       Nonbond force                   0.00 Other:            0.00
#          Bond energy                     0.00 Other:            0.00
#          Angle energy                    0.00 Other:            0.00
#          Dihedral energy                 0.00 Other:            0.00
#          Restraints energy               0.00 Other:            0.00
#       INTRNL energy                   0.01 Other:            0.00
#       Comm energy                     0.00 Other:            0.00
#       Comm force                      0.00 Other:            0.00
#    Energy time                     0.02 Other:            0.01
#  Total time                     46.31 Other:           46.22
#          $$$$$$  Average   profile $$$$$
#    List time                       0.06 Other:            0.00
#       Nonbond force                   0.00 Other:            0.00
#          Bond energy                     0.00 Other:            0.00
#          Angle energy                    0.00 Other:            0.00
#          Dihedral energy                 0.00 Other:            0.00
#          Restraints energy               0.00 Other:            0.00
#       INTRNL energy                   0.01 Other:            0.00
#       Comm energy                     0.00 Other:            0.00
#       Comm force                      0.00 Other:            0.00
#    Energy time                     0.02 Other:            0.01
#  Total time                     46.31 Other:           46.22
#
#                     NORMAL TERMINATION BY NORMAL STOP
#                     MOST SEVERE WARNING WAS AT LEVEL  0
#
#                     $$$$$ JOB ACCOUNTING INFORMATION $$$$$
#                      ELAPSED TIME:    46.45  SECONDS
#                          CPU TIME:    44.41  SECONDS

# %%
fftdock(protein, ligand, fftdock_dockdir, fftdock_scorefile, fftdock_eps, griddir, scriptdir, faddir, liganddir, fftdock_poses)

# %%
#Minimize poses in explicit protein
#Minimize fftdock poses in explicit protein
prot_dockdir = os.path.join('poses', f'{protein}_{ligand}_prot_0.75')
prot_eps = 0.75
prot_scorefile = f'scores/{protein}_{ligand}_prot_0.75.dat'
os.makedirs(prot_dockdir, exist_ok = True)

#Minimize fftdock poses in explicit protein
def prot(protein: str,
         ligand: str,
         dockdir: str,
         scorefile: str,
         eps_study: int,
         fftdockdir: str,
         scriptdir:str,
         faddir:str,
         num_poses:int,
         liganddir:str,):
    
    #Minimize on explicit protein 
    prot_min_out = os.popen(f'{charmm_exec} -i {scriptdir}/protmin.inp protein={protein} ligand={ligand} poses={num_poses} ' + 
        f'dockdir={dockdir} scorefile={scorefile} faddir={faddir} liganddir={liganddir} ' + 
        f'fftdockdir={fftdockdir} epsilon={eps_study} scriptdir={scriptdir}').read()
    print(prot_min_out)
    
    return

# %%
prot(protein, ligand, prot_dockdir, prot_scorefile, prot_eps, fftdock_dockdir, scriptdir, faddir, fftdock_poses, liganddir)
# Out:
# [gollum154][[12078,1],0][../../../../../openmpi-3.1.2/opal/mca/btl/openib/btl_openib_component.c:1671:init_one_device] error obtaining device attributes for mlx5_0 errno says Protocol not supported
# --------------------------------------------------------------------------
# WARNING: There was an error initializing an OpenFabrics device.
#
#   Local host:   gollum154
#   Local device: mlx5_0
# --------------------------------------------------------------------------
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
#Cluster generated poses
#Cluster poses with cluster_pl and return output
def run_clusterpl(protein, ligand, dockdir, radius = 1):
    cmd = f'cluster.pl -kclust -nolsqfit -radius {radius} -selmode heavy {dockdir}/{protein}_{ligand}_*.pdb'
    cluster_out = os.popen(cmd).read()
    return cluster_out

#Read in cluster output and return list of clusters
def read_clusters(protein, ligand, dockdir, cluster_out):
    clusters = []
    cluster = []
    start = False
    
    for line in cluster_out.splitlines():
        if 'cluster t.' in line:
            if cluster:
                clusters.append(cluster)
            cluster = []
            start = True
        elif start:
            index = re.findall('{}/{}_{}_(\S+).pdb'.format(dockdir, protein, ligand), line)[0]
            cluster.append(index)
    if cluster:
        clusters.append(cluster)
    
    #sort clusters by size: largest -> smallest
    clusters.sort(key = len, reverse=True)  
    
    return clusters

#returns dictionary to map each pose from fftdock or minimization to its energy
def read_scores(scorefile):
    index_energies = dict()
    #get index and associated energy for score.dat
    with open(scorefile, 'r') as min_score_reader:
        for line in min_score_reader.read().splitlines():
            index, index_energy = line.split()[0], line.split()[1]
            index_energies[index] = float(index_energy)

    return index_energies

#based on dictionary from read_scores, calculate stats for given cluster
def cluster_stats(cluster, index_energies):
    cluster_dict = dict()
    cluster_dict['cluster'] = cluster
    cluster_dict['size'] = len(cluster)
    energies = []
    min_index = -1
    min_ener = ''
    for index in cluster:
        index_energy = index_energies[index]
        energies.append(float(index_energy))
        if not min_ener or index_energy < min_ener:
            min_ener = round(index_energy,2)
            min_index = index
    cluster_dict['min_ener'] = min_ener
    cluster_dict['min_index'] = min_index
    average = round(np.average(energies),2)
    std = round(np.std(energies),2)
    cluster_dict['average energy'] = average
    cluster_dict['std energy'] = std
    return cluster_dict

# %%
cluster_out = run_clusterpl(protein, ligand, prot_dockdir)
index_energies = read_scores(prot_scorefile)
print(cluster_out)
# Out:
# /export/apps/CentOS7/mmtsb/src/feig/toolset//bin/kclust -pdb -centroid -cdist -radius 1 -iterate -maxerr 0.01 -mode rmsd -heavy
# # cluster file
# # automatically generated on: Wed Dec  7 12:58:49 2022
# # mode: rmsd, filetype: pdb, lsqfit: 0, selmode: heavy
# @cluster t has 500 elements, 136 subclusters
# 1 poses/tropb_2_prot_0.75/tropb_2_100.pdb
# 2 poses/tropb_2_prot_0.75/tropb_2_101.pdb
# 3 poses/tropb_2_prot_0.75/tropb_2_102.pdb
# 4 poses/tropb_2_prot_0.75/tropb_2_103.pdb
# 5 poses/tropb_2_prot_0.75/tropb_2_104.pdb
# 6 poses/tropb_2_prot_0.75/tropb_2_105.pdb
# 7 poses/tropb_2_prot_0.75/tropb_2_106.pdb
# 8 poses/tropb_2_prot_0.75/tropb_2_107.pdb
# 9 poses/tropb_2_prot_0.75/tropb_2_108.pdb
# 10 poses/tropb_2_prot_0.75/tropb_2_109.pdb
# 11 poses/tropb_2_prot_0.75/tropb_2_10.pdb
# 12 poses/tropb_2_prot_0.75/tropb_2_110.pdb
# 13 poses/tropb_2_prot_0.75/tropb_2_111.pdb
# 14 poses/tropb_2_prot_0.75/tropb_2_112.pdb
# 444 poses/tropb_2_prot_0.75/tropb_2_4.pdb 0.349438
# @cluster t.67 has 2 elements, 0 subclusters
# 176 poses/tropb_2_prot_0.75/tropb_2_259.pdb 0.448688
# 213 poses/tropb_2_prot_0.75/tropb_2_292.pdb 0.448688
# @cluster t.68 has 3 elements, 0 subclusters
# 134 poses/tropb_2_prot_0.75/tropb_2_220.pdb 0.541378
# 179 poses/tropb_2_prot_0.75/tropb_2_261.pdb 0.319175
# 419 poses/tropb_2_prot_0.75/tropb_2_478.pdb 0.356333
# @cluster t.69 has 2 elements, 0 subclusters
# 187 poses/tropb_2_prot_0.75/tropb_2_269.pdb 0.413443
# 244 poses/tropb_2_prot_0.75/tropb_2_31.pdb 0.413443
# @cluster t.70 has 1 elements, 0 subclusters
# 189 poses/tropb_2_prot_0.75/tropb_2_270.pdb 0.000000
# @cluster t.71 has 1 elements, 0 subclusters
# 191 poses/tropb_2_prot_0.75/tropb_2_272.pdb 0.000000
# @cluster t.72 has 1 elements, 0 subclusters
# 193 poses/tropb_2_prot_0.75/tropb_2_274.pdb 0.000000
# @cluster t.73 has 1 elements, 0 subclusters
# 196 poses/tropb_2_prot_0.75/tropb_2_277.pdb 0.000000
# @cluster t.74 has 1 elements, 0 subclusters
# 198 poses/tropb_2_prot_0.75/tropb_2_279.pdb 0.000000
# @cluster t.75 has 1 elements, 0 subclusters
# 204 poses/tropb_2_prot_0.75/tropb_2_284.pdb 0.000000
# @cluster t.76 has 1 elements, 0 subclusters
# 209 poses/tropb_2_prot_0.75/tropb_2_289.pdb 0.000000
# @cluster t.77 has 1 elements, 0 subclusters
# 211 poses/tropb_2_prot_0.75/tropb_2_290.pdb 0.000000
# @cluster t.78 has 4 elements, 0 subclusters
# 215 poses/tropb_2_prot_0.75/tropb_2_294.pdb 0.448755
# 307 poses/tropb_2_prot_0.75/tropb_2_377.pdb 0.346382
# 352 poses/tropb_2_prot_0.75/tropb_2_417.pdb 0.730169
# 436 poses/tropb_2_prot_0.75/tropb_2_493.pdb 0.476055
# @cluster t.79 has 2 elements, 0 subclusters
# 220 poses/tropb_2_prot_0.75/tropb_2_299.pdb 0.489710
# 251 poses/tropb_2_prot_0.75/tropb_2_326.pdb 0.489710
# @cluster t.80 has 2 elements, 0 subclusters
# 223 poses/tropb_2_prot_0.75/tropb_2_300.pdb 0.155378
# 302 poses/tropb_2_prot_0.75/tropb_2_372.pdb 0.155378
# @cluster t.81 has 3 elements, 0 subclusters
# 107 poses/tropb_2_prot_0.75/tropb_2_197.pdb 0.217279
# 225 poses/tropb_2_prot_0.75/tropb_2_302.pdb 0.438486
# 235 poses/tropb_2_prot_0.75/tropb_2_311.pdb 0.290282
# @cluster t.82 has 4 elements, 0 subclusters
# 230 poses/tropb_2_prot_0.75/tropb_2_307.pdb 0.389649
# 284 poses/tropb_2_prot_0.75/tropb_2_356.pdb 0.220830
# 305 poses/tropb_2_prot_0.75/tropb_2_375.pdb 0.243552
# 37 poses/tropb_2_prot_0.75/tropb_2_133.pdb 0.238459
# 262 poses/tropb_2_prot_0.75/tropb_2_336.pdb 0.409256
# @cluster t.95 has 3 elements, 0 subclusters
# 264 poses/tropb_2_prot_0.75/tropb_2_338.pdb 0.315166
# 267 poses/tropb_2_prot_0.75/tropb_2_340.pdb 0.157165
# 457 poses/tropb_2_prot_0.75/tropb_2_60.pdb 0.324318
# @cluster t.96 has 8 elements, 0 subclusters
# 21 poses/tropb_2_prot_0.75/tropb_2_119.pdb 0.424225
# 219 poses/tropb_2_prot_0.75/tropb_2_298.pdb 0.403314
# 270 poses/tropb_2_prot_0.75/tropb_2_343.pdb 0.562614
# 308 poses/tropb_2_prot_0.75/tropb_2_378.pdb 0.272661
# 314 poses/tropb_2_prot_0.75/tropb_2_383.pdb 0.140741
# 345 poses/tropb_2_prot_0.75/tropb_2_410.pdb 0.485967
# 350 poses/tropb_2_prot_0.75/tropb_2_415.pdb 0.476277
# 471 poses/tropb_2_prot_0.75/tropb_2_73.pdb 0.473275
# @cluster t.97 has 2 elements, 0 subclusters
# 271 poses/tropb_2_prot_0.75/tropb_2_344.pdb 0.191950
# 306 poses/tropb_2_prot_0.75/tropb_2_376.pdb 0.191950
# @cluster t.98 has 1 elements, 0 subclusters
# 275 poses/tropb_2_prot_0.75/tropb_2_348.pdb 0.000000
# @cluster t.99 has 6 elements, 0 subclusters
# 276 poses/tropb_2_prot_0.75/tropb_2_349.pdb 0.719393
# 282 poses/tropb_2_prot_0.75/tropb_2_354.pdb 0.262716
# 285 poses/tropb_2_prot_0.75/tropb_2_357.pdb 0.474994
# 403 poses/tropb_2_prot_0.75/tropb_2_463.pdb 0.105026
# 468 poses/tropb_2_prot_0.75/tropb_2_70.pdb 0.328427
# 474 poses/tropb_2_prot_0.75/tropb_2_76.pdb 0.407457
# @cluster t.100 has 1 elements, 0 subclusters
# 278 poses/tropb_2_prot_0.75/tropb_2_350.pdb 0.000000
# @cluster t.101 has 2 elements, 0 subclusters
# 279 poses/tropb_2_prot_0.75/tropb_2_351.pdb 0.297604
# 442 poses/tropb_2_prot_0.75/tropb_2_499.pdb 0.297604
# @cluster t.102 has 1 elements, 0 subclusters
# 283 poses/tropb_2_prot_0.75/tropb_2_355.pdb 0.000000
# @cluster t.103 has 1 elements, 0 subclusters
# 294 poses/tropb_2_prot_0.75/tropb_2_365.pdb 0.000000
# @cluster t.104 has 1 elements, 0 subclusters
# 297 poses/tropb_2_prot_0.75/tropb_2_368.pdb 0.000000
# @cluster t.105 has 1 elements, 0 subclusters
# 298 poses/tropb_2_prot_0.75/tropb_2_369.pdb 0.000000
# @cluster t.106 has 4 elements, 0 subclusters
# 174 poses/tropb_2_prot_0.75/tropb_2_257.pdb 0.498348
# 227 poses/tropb_2_prot_0.75/tropb_2_304.pdb 0.400812
# 319 poses/tropb_2_prot_0.75/tropb_2_388.pdb 0.452445
# 407 poses/tropb_2_prot_0.75/tropb_2_467.pdb 0.327793
# @cluster t.107 has 1 elements, 0 subclusters
# 326 poses/tropb_2_prot_0.75/tropb_2_394.pdb 0.000000
# @cluster t.108 has 2 elements, 0 subclusters
# 331 poses/tropb_2_prot_0.75/tropb_2_399.pdb 0.352241
# 380 poses/tropb_2_prot_0.75/tropb_2_442.pdb 0.352241
# @cluster t.109 has 2 elements, 0 subclusters
# 334 poses/tropb_2_prot_0.75/tropb_2_400.pdb 0.057026
# 387 poses/tropb_2_prot_0.75/tropb_2_449.pdb 0.057026
# @cluster t.110 has 1 elements, 0 subclusters
# 339 poses/tropb_2_prot_0.75/tropb_2_405.pdb 0.000000
# @cluster t.111 has 1 elements, 0 subclusters
# 341 poses/tropb_2_prot_0.75/tropb_2_407.pdb 0.000000
# @cluster t.112 has 1 elements, 0 subclusters
# 346 poses/tropb_2_prot_0.75/tropb_2_411.pdb 0.000000
# @cluster t.113 has 3 elements, 0 subclusters
# 127 poses/tropb_2_prot_0.75/tropb_2_214.pdb 0.621253
# 347 poses/tropb_2_prot_0.75/tropb_2_412.pdb 0.615022
# 385 poses/tropb_2_prot_0.75/tropb_2_447.pdb 0.409768
# @cluster t.114 has 1 elements, 0 subclusters
# 348 poses/tropb_2_prot_0.75/tropb_2_413.pdb 0.000000
# @cluster t.115 has 1 elements, 0 subclusters
# 349 poses/tropb_2_prot_0.75/tropb_2_414.pdb 0.000000
# @cluster t.116 has 3 elements, 0 subclusters
# 351 poses/tropb_2_prot_0.75/tropb_2_416.pdb 0.237624
# 353 poses/tropb_2_prot_0.75/tropb_2_418.pdb 0.319536
# 438 poses/tropb_2_prot_0.75/tropb_2_495.pdb 0.182907
# @cluster t.117 has 1 elements, 0 subclusters
# 358 poses/tropb_2_prot_0.75/tropb_2_422.pdb 0.000000
# @cluster t.118 has 1 elements, 0 subclusters
# 360 poses/tropb_2_prot_0.75/tropb_2_424.pdb 0.000000
# @cluster t.119 has 5 elements, 0 subclusters
# 363 poses/tropb_2_prot_0.75/tropb_2_427.pdb 0.349347
# 473 poses/tropb_2_prot_0.75/tropb_2_75.pdb 0.203828
# 479 poses/tropb_2_prot_0.75/tropb_2_80.pdb 0.508595
# 482 poses/tropb_2_prot_0.75/tropb_2_83.pdb 0.208675
# 499 poses/tropb_2_prot_0.75/tropb_2_99.pdb 0.498483
# @cluster t.120 has 3 elements, 0 subclusters
# 365 poses/tropb_2_prot_0.75/tropb_2_429.pdb 0.295664
# 370 poses/tropb_2_prot_0.75/tropb_2_433.pdb 0.283350
# 431 poses/tropb_2_prot_0.75/tropb_2_489.pdb 0.439571
# @cluster t.121 has 1 elements, 0 subclusters
# 373 poses/tropb_2_prot_0.75/tropb_2_436.pdb 0.000000
# @cluster t.122 has 1 elements, 0 subclusters
# 375 poses/tropb_2_prot_0.75/tropb_2_438.pdb 0.000000
# @cluster t.123 has 1 elements, 0 subclusters
# 378 poses/tropb_2_prot_0.75/tropb_2_440.pdb 0.000000
# @cluster t.124 has 1 elements, 0 subclusters
# 384 poses/tropb_2_prot_0.75/tropb_2_446.pdb 0.000000
# @cluster t.125 has 1 elements, 0 subclusters
# 394 poses/tropb_2_prot_0.75/tropb_2_455.pdb 0.000000
# @cluster t.126 has 1 elements, 0 subclusters
# 402 poses/tropb_2_prot_0.75/tropb_2_462.pdb 0.000000
# @cluster t.127 has 1 elements, 0 subclusters
# 406 poses/tropb_2_prot_0.75/tropb_2_466.pdb 0.000000
# @cluster t.128 has 1 elements, 0 subclusters
# 408 poses/tropb_2_prot_0.75/tropb_2_468.pdb 0.000000
# @cluster t.129 has 1 elements, 0 subclusters
# 409 poses/tropb_2_prot_0.75/tropb_2_469.pdb 0.000000
# @cluster t.130 has 1 elements, 0 subclusters
# 410 poses/tropb_2_prot_0.75/tropb_2_46.pdb 0.000000
# @cluster t.131 has 2 elements, 0 subclusters
# 420 poses/tropb_2_prot_0.75/tropb_2_479.pdb 0.434155
# 440 poses/tropb_2_prot_0.75/tropb_2_497.pdb 0.434155
# @cluster t.132 has 2 elements, 0 subclusters
# 122 poses/tropb_2_prot_0.75/tropb_2_20.pdb 0.393491
# 423 poses/tropb_2_prot_0.75/tropb_2_481.pdb 0.393491
# @cluster t.133 has 1 elements, 0 subclusters
# 427 poses/tropb_2_prot_0.75/tropb_2_485.pdb 0.000000
# @cluster t.134 has 1 elements, 0 subclusters
# 429 poses/tropb_2_prot_0.75/tropb_2_487.pdb 0.000000
# @cluster t.135 has 1 elements, 0 subclusters
# 435 poses/tropb_2_prot_0.75/tropb_2_492.pdb 0.000000
# @cluster t.136 has 1 elements, 0 subclusters
# 437 poses/tropb_2_prot_0.75/tropb_2_494.pdb 0.000000

# %%
clusters = read_clusters(protein, ligand, prot_dockdir, cluster_out)
cluster_dicts = [cluster_stats(cluster, index_energies) for cluster in clusters]

# %%
cluster_df = pd.DataFrame.from_records(cluster_dicts)
cluster_df = cluster_df.sort_values(by=['min_ener'])
cluster_df = cluster_df.reset_index(drop=True)
cluster_df.to_excel(f'cluster/{protein}_{ligand}_prot_0.75.xlsx')
cluster_df
# Out:
#                                                cluster  size  min_ener  \
# 0                                                [422]     1    -54.22
# 1    [107, 122, 143, 166, 183, 212, 223, 345, 347, ...    13    -48.71
# 2                           [1, 367, 392, 39, 452, 63]     6    -47.17
# 3                  [179, 275, 297, 396, 460, 475, 477]     7    -45.61
# 4                      [121, 158, 161, 21, 360, 55, 8]     7    -42.97
# ..                                                 ...   ...       ...
# 131                       [244, 28, 382, 426, 441, 53]     6   5005.82
# 132                                    [197, 302, 311]     3   5018.36
# 133                                               [32]     1   5022.10
# 134                                          [116, 96]     2   5112.42
# 135                                              [274]     1   6395.71
#
#     min_index  average energy  std energy
# 0         422          -54.22        0.00
# 1         381          -35.73        9.14
# 2         367          -29.69       12.23
# 3         396          -25.63        9.39
# 4           8          -26.39        7.85
# ..        ...             ...         ...
# 131       441         5035.67       23.38
# 132       197         5053.08       30.07
# 133        32         5022.10        0.00
# 134       116         5114.75        2.33
# 135       274         6395.71        0.00
#
# [136 rows x 6 columns]
